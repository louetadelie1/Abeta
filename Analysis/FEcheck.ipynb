# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### FE check

# %%
# Use pluemd driver to create 3 fes files and disregard the first one 
for i in range(1,3):
    fes=np.genfromtxt("/pool/work/adelie/results_32.01/FE/FES/fes_" + str(i) + ".dat")
    plt.plot(fes[:,0],fes[:,1],label=str(round((i*15)+15)) + " ns")

plt.xlabel("Collective variable")
plt.ylabel("Free energy (kJ/mol)")
#plt.xlim([-4,4])
plt.legend()
plt.ylim([0,50])
plt.show()
